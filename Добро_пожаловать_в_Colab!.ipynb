# %% [markdown]
# <a href="https://colab.research.google.com/github/RMZ111-datasciense/boshlanish/blob/main/%D0%94%D0%BE%D0%B1%D1%80%D0%BE_%D0%BF%D0%BE%D0%B6%D0%B0%D0%BB%D0%BE%D0%B2%D0%B0%D1%82%D1%8C_%D0%B2_Colab!.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# === 1. KERAKLI KUTUBXONALAR ===
import pandas as pd
import matplotlib.pyplot as plt

# === 2. MA'LUMOTLAR YARATISH ===
data = {
    "Viloyat": ["Toshkent", "Samarqand", "Farg‘ona", "Namangan", "Andijon",
                 "Buxoro", "Navoiy", "Xorazm", "Qashqadaryo", "Surxondaryo"],
    "Aholi (mln)": [3.0, 2.2, 2.1, 1.9, 2.0, 1.8, 1.1, 1.7, 2.3, 2.5],
    "O‘rtacha daromad (ming so‘m)": [4200, 3500, 3300, 3100, 3000, 3700, 4800, 3400, 3200, 2900],
    "Ishsizlik (%)": [6.0, 7.5, 8.1, 8.3, 8.5, 7.0, 5.2, 8.0, 8.4, 8.7]
}

df = pd.DataFrame(data)

# === 3. ASOSIY TAHLIL ===
print("💰 Eng yuqori daromadli viloyat:")
print(df.loc[df["O‘rtacha daromad (ming so‘m)"].idxmax()])

print("\n😕 Eng past daromadli viloyat:")
print(df.loc[df["O‘rtacha daromad (ming so‘m)"].idxmin()])

# === 4. KORRELYATSIYA TAHLILI ===
corr = df["Aholi (mln)"].corr(df["O‘rtacha daromad (ming so‘m)"])
print(f"\n📈 Aholi soni va daromad o‘rtasidagi bog‘liqlik darajasi (korrelyatsiya): {corr:.2f}")

# Jadvalni chiqaramiz
df
# === DAROMADLAR GRAFIGI ===
plt.figure(figsize=(10,6))
plt.bar(df["Viloyat"], df["O‘rtacha daromad (ming so‘m)"], color='skyblue')
plt.title("Viloyatlar bo‘yicha o‘rtacha daromad")
plt.xlabel("Viloyat")
plt.ylabel("Daromad (ming so‘m)")
plt.xticks(rotation=45)
plt.show()

# === AHOLI SONI VA DAROMADNING SCATTER GRAFIGI ===
plt.figure(figsize=(8,6))
plt.scatter(df["Aholi (mln)"], df["O‘rtacha daromad (ming so‘m)"], color='orange')
plt.title("Aholi soni va daromad o‘rtasidagi bog‘liqlik")
plt.xlabel("Aholi (mln)")
plt.ylabel("Daromad (ming so‘m)")
plt.grid(True)
plt.show()
print("🧾 Xulosa:")
print("""
- Eng boy viloyat: Navoiy
- Eng past daromadli viloyat: Surxondaryo
- Korrelyatsiya musbat (aholi ko‘p bo‘lsa, daromad ko‘tarilmoqda)
- Grafiklar orqali ko‘ramizki, Toshkent va Navoiy iqtisodiy jihatdan yuqorida.
""")
# Out:
# 💰 Eng yuqori daromadli viloyat:
# Viloyat                         Navoiy
# Aholi (mln)                        1.1
# O‘rtacha daromad (ming so‘m)      4800
# Ishsizlik (%)                      5.2
# Name: 6, dtype: object
#
# 😕 Eng past daromadli viloyat:
# Viloyat                         Surxondaryo
# Aholi (mln)                             2.5
# O‘rtacha daromad (ming so‘m)           2900
# Ishsizlik (%)                           8.7
# Name: 9, dtype: object
#
# 📈 Aholi soni va daromad o‘rtasidagi bog‘liqlik darajasi (korrelyatsiya): -0.32
# 🧾 Xulosa:
#
# - Eng boy viloyat: Navoiy
# - Eng past daromadli viloyat: Surxondaryo
# - Korrelyatsiya musbat (aholi ko‘p bo‘lsa, daromad ko‘tarilmoqda)
# - Grafiklar orqali ko‘ramizki, Toshkent va Navoiy iqtisodiy jihatdan yuqorida.
