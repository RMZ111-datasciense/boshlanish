# %% [markdown]
# <a href="https://colab.research.google.com/github/RMZ111-datasciense/boshlanish/blob/main/%D0%94%D0%BE%D0%B1%D1%80%D0%BE_%D0%BF%D0%BE%D0%B6%D0%B0%D0%BB%D0%BE%D0%B2%D0%B0%D1%82%D1%8C_%D0%B2_Colab!.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# 10 ta mahsulot nomlari
mahsulotlar = ["Olma", "Banan", "Shaftoli", "Apelsin", "Uzum",
               "Anor", "Gilos", "Qovun", "Tarvuz", "Limon"]

# Narxlar va sotilgan miqdorlar
np.random.seed(42)
narxlar = np.random.randint(10000, 30000, 10)
sotilgan = np.random.randint(50, 200, 10)
df = pd.DataFrame({
    "Mahsulot": mahsulotlar,
    "Narx": narxlar,
    "Sotilgan_soni": sotilgan
})

# Umumiy daromad ustuni
df["Daromad"] = df["Narx"] * df["Sotilgan_soni"]

df
print("📊 Umumiy statistik ma’lumotlar:")
print(df.describe())

print("\n💰 Eng ko‘p daromad keltirgan mahsulot:")
print(df.loc[df["Daromad"].idxmax()])

print("\n📉 Eng kam daromad keltirgan mahsulot:")
print(df.loc[df["Daromad"].idxmin()])
plt.figure(figsize=(9,5))
plt.bar(df["Mahsulot"], df["Daromad"], color="skyblue", edgecolor="black")
plt.title("Mahsulotlar bo‘yicha umumiy daromad", fontsize=14)
plt.xlabel("Mahsulotlar")
plt.ylabel("Daromad (so‘m)")
plt.xticks(rotation=45)
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.show()
# Out:
# 📊 Umumiy statistik ma’lumotlar:
#                Narx  Sotilgan_soni       Daromad
# count     10.000000      10.000000  1.000000e+01
# mean   19862.000000     126.500000  2.343182e+06
# std     5344.281846      50.684756  7.678952e+05
# min    10860.000000      51.000000  1.085484e+06
# 25%    15608.750000      90.750000  2.023176e+06
# 50%    21323.500000     122.000000  2.263084e+06
# 75%    23808.250000     172.500000  2.520678e+06
# max    26850.000000     199.000000  3.946635e+06
#
# 💰 Eng ko‘p daromad keltirgan mahsulot:
# Mahsulot            Olma
# Narx               25795
# Sotilgan_soni        153
# Daromad          3946635
# Name: 0, dtype: object
#
# 📉 Eng kam daromad keltirgan mahsulot:
# Mahsulot            Uzum
# Narx               21284
# Sotilgan_soni         51
# Daromad          1085484
# Name: 4, dtype: object
